# %% [markdown]
# # Clustering K-Means

# %% [markdown]
# ## Importar librerías

# %%
import numpy as np ##cálculos científicos
import pandas as pd ## analisis de datos
import matplotlib.pyplot as plt ## creacion de graficos
import seaborn as sns ## creacion de graficos
from sklearn.preprocessing import LabelEncoder #Para convertir en variables numéricas
from sklearn.cluster import KMeans ## para clustering con K-means


# %matplotlib inline

# %% [markdown]
# ## Importar datos

# %%
df = pd.read_csv(r'D:\Lucas\Universidad de Palermo\4° Año\2- Segundo Semestre\Big Data\Herramienta Data Preparation\data set\archive\DFs\transaction-data-f19982.csv')
df_procesado = pd.read_csv(r'D:\Lucas\Universidad de Palermo\4° Año\2- Segundo Semestre\Big Data\Herramienta Data Preparation\data set\archive\DFs\updated-dataframe-1aa1ec.csv')
df_normalizado = pd.read_csv(r'D:\Lucas\Universidad de Palermo\4° Año\2- Segundo Semestre\Big Data\Herramienta Data Preparation\data set\archive\DFs\normalized-dataset-27495c.csv')

# %%
df_procesado
# Out:
#         transaction_id  transaction_qty  store_location  unit_price  \
# 0                    1                2               2        3.00
# 1                    2                2               2        3.10
# 2                    3                2               2        4.50
# 3                    4                1               2        2.00
# 4                    5                2               2        3.10
# ...                ...              ...             ...         ...
# 149111          149452                2               1        2.50
# 149112          149453                2               1        3.00
# 149113          149454                1               1        3.00
# 149114          149455                1               1        3.75
# 149115          149456                2               1        0.80
#
#         product_category  product_type  product_detail  periodo  temporada
# 0                      2            13              32        0          0
# 1                      8             4              71        0          0
# 2                      4            17              20        0          0
# 3                      2            10              60        0          0
# 4                      8             4              71        0          0
# ...                  ...           ...             ...      ...        ...
# 149111                 8             6              64        1          2
# 149112                 8             3              26        1          2
# 149113                 8             6              63        1          2
# 149114                 2             0               5        1          2
# 149115                 5            26              38        1          2
#
# [149116 rows x 9 columns]

# %% [markdown]
# ## Simplificación  del análisis

# %% [markdown]
# Data Preparation realizado con ChatCSV

# %% [markdown]
# ## Aplicación del método Clustering K-Means al dataset de Maven Coffe

# %%
clustering = KMeans(n_clusters = 3, max_iter = 300) #Crea el modelo
clustering.fit(df_normalizado) #Aplica el modelo al dataset
# Out:
# KMeans(n_clusters=3)

# %%
KMeans(algorithm='auto',copy_x=True,init='k-means++',max_iter=300, n_clusters=3,n_init=10,n_jobs=None,precompute_distances='auto',random_state=None,tol=0.0001,verbose=0)
# Out:
# KMeans(n_clusters=3, n_jobs=None, precompute_distances='auto')

# %%
df_normalizado['KMeans_Clusters'] = clustering.labels_  # Agregamos la clasificación de cada elemento según el cluster al que pertenece
df_normalizado.head()
# Out:
#    transaction_id  transaction_qty  store_location  unit_price  \
# 0        0.000000         0.142857             1.0    0.049774
# 1        0.000007         0.142857             1.0    0.052036
# 2        0.000013         0.142857             1.0    0.083710
# 3        0.000020         0.000000             1.0    0.027149
# 4        0.000027         0.142857             1.0    0.052036
#
#    product_category  product_type  product_detail  periodo  temporada  \
# 0              0.25      0.464286        0.405063      0.0        0.0
# 1              1.00      0.142857        0.898734      0.0        0.0
# 2              0.50      0.607143        0.253165      0.0        0.0
# 3              0.25      0.357143        0.759494      0.0        0.0
# 4              1.00      0.142857        0.898734      0.0        0.0
#
#    KMeans_Clusters
# 0                1
# 1                2
# 2                1
# 3                1
# 4                2

# %% [markdown]
# ### Visualización de los clusters

# %% [markdown]
# Se aplica el Análisis de Componentes Principales (PCA) para reducir la dimensionalidad y agrupar las características en la visualización

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_coffe = pca.fit_transform(df_normalizado)
pca_df_coffe = pd.DataFrame(data = pca_coffe, columns = ['Componente_1', 'Componente_2'])
pca_df_coffe = pd.concat([pca_df_coffe,df_normalizado[['KMeans_Clusters']]], axis=1)

pca_df_coffe
# Out:
#         Componente_1  Componente_2  KMeans_Clusters
# 0           0.321221     -0.453657                1
# 1           1.357522      0.409313                2
# 2           0.342317     -0.411223                1
# 3           0.349466     -0.277361                1
# 4           1.357523      0.409312                2
# ...              ...           ...              ...
# 149111      1.094660      0.622518                2
# 149112      1.074342      0.500691                2
# 149113      1.093276      0.614286                2
# 149114     -0.778365     -0.106635                0
# 149115      0.099890     -0.120579                1
#
# [149116 rows x 3 columns]

# %%
fig = plt.figure(figsize=(6,6))

ax = fig.add_subplot(1,1,1)
ax.set_xlabel('Componente 1', fontsize=15)
ax.set_ylabel('Componente 2', fontsize=15)
ax.set_title('Componentes Principales', fontsize=20)

color_theme = np.array(["blue", "green", "orange","red","purple"])
# Reducimos la opacidad y el tamaño de los puntos
ax.scatter(x=pca_df_coffe.Componente_1, y=pca_df_coffe.Componente_2, 
           c=color_theme[pca_df_coffe.KMeans_Clusters], s=20, alpha=0.5)

plt.show()

# %% [markdown]
# ## Interpretación de los resultados

# %%
# Mapeo de valores numéricos a texto
mapeo_periodo = {
    0: 'Mañana',
    2: 'Tarde',
    1: 'Noche'
}

mapeo_temporada = {
    0: 'Invierno',
    1: 'Primavera',
    2: 'Verano',
    3: 'Otoño'
}

# Revertir la conversión usando el diccionario
df['periodo'] = df_procesado['periodo'].map(mapeo_periodo)
df['temporada'] = df_procesado['temporada'].map(mapeo_temporada)
df['KMeans_Clusters'] = df_normalizado['KMeans_Clusters']

# %%
df[df['transaction_id']==142172]
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 141835          142172       2023-06-24         13:32:43                2
#
#         store_id store_location  product_id  unit_price product_category  \
# 141835         3        Astoria          39        4.25           Coffee
#
#             product_type product_detail periodo temporada  KMeans_Clusters
# 141835  Barista Espresso       Latte Rg   Tarde    Verano                0

# %%
cluster_0 = df[df['KMeans_Clusters'] == 0]
cluster_1 = df[df['KMeans_Clusters'] == 1]
cluster_2 = df[df['KMeans_Clusters'] == 2]
cluster_3 = df[df['KMeans_Clusters'] == 3]
cluster_4 = df[df['KMeans_Clusters'] == 4]

# %% [markdown]
# #### Cluster 0

# %%
cluster_0
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 156                157       2023-01-01         12:00:20                1
# 157                158       2023-01-01         12:01:00                2
# 158                159       2023-01-01         12:01:20                2
# 159                160       2023-01-01         12:01:20                1
# 160                161       2023-01-01         12:03:09                1
# ...                ...              ...              ...              ...
# 149091          149432       2023-06-30         19:35:24                2
# 149095          149436       2023-06-30         19:44:46                1
# 149097          149438       2023-06-30         19:45:16                1
# 149105          149446       2023-06-30         19:53:46                1
# 149114          149455       2023-06-30         20:57:19                1
#
#         store_id   store_location  product_id  unit_price    product_category  \
#
# 149108                  Scone              Cranberry Scone   Noche    Verano
# 149115          Regular syrup               Hazelnut syrup   Noche    Verano
#
#         KMeans_Clusters
# 0                     1
# 2                     1
# 3                     1
# 5                     1
# 6                     1
# ...                 ...
# 149103                1
# 149104                1
# 149106                1
# 149108                1
# 149115                1
#
# [62080 rows x 14 columns]

# %% [markdown]
# #### Cluster 2

# %%
cluster_2
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 1                    2       2023-01-01         07:08:56                2
# 4                    5       2023-01-01         07:22:41                2
# 10                  11       2023-01-01         07:43:05                1
# 12                  13       2023-01-01         07:45:51                1
# 13                  14       2023-01-01         07:48:19                1
# ...                ...              ...              ...              ...
# 149109          149450       2023-06-30         20:08:38                2
# 149110          149451       2023-06-30         20:16:31                2
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
#
#         store_id   store_location  product_id  unit_price product_category  \
# 1              5  Lower Manhattan          57        3.10              Tea
# 4              5  Lower Manhattan          57        3.10              Tea
# 10             5  Lower Manhattan          56        2.55              Tea
# 12             5  Lower Manhattan          51        3.00              Tea
# 13             5  Lower Manhattan          57        3.10              Tea
# ...          ...              ...         ...         ...              ...
# 149109         8   Hell's Kitchen          55        4.00              Tea
# 149110         5  Lower Manhattan          42        2.50              Tea
# 149111         8   Hell's Kitchen          44        2.50              Tea
# 149112         8   Hell's Kitchen          49        3.00              Tea
# 149113         8   Hell's Kitchen          45        3.00              Tea
#
#              product_type            product_detail periodo temporada  \
# 1         Brewed Chai tea  Spicy Eye Opener Chai Lg  Mañana  Invierno
# 4         Brewed Chai tea  Spicy Eye Opener Chai Lg  Mañana  Invierno
# 10        Brewed Chai tea  Spicy Eye Opener Chai Rg  Mañana  Invierno
# 12       Brewed Black tea              Earl Grey Lg  Mañana  Invierno
# 13        Brewed Chai tea  Spicy Eye Opener Chai Lg  Mañana  Invierno
# ...                   ...                       ...     ...       ...
# 149109    Brewed Chai tea   Morning Sunrise Chai Lg   Noche    Verano
# 149110  Brewed herbal tea            Lemon Grass Rg   Noche    Verano
# 149111  Brewed herbal tea             Peppermint Rg   Noche    Verano
# 149112   Brewed Black tea      English Breakfast Lg   Noche    Verano
# 149113  Brewed herbal tea             Peppermint Lg   Noche    Verano
#
#         KMeans_Clusters
# 1                     2
# 4                     2
# 10                    2
# 12                    2
# 13                    2
# ...                 ...
# 149109                2
# 149110                2
# 149111                2
# 149112                2
# 149113                2
#
# [29857 rows x 14 columns]

# %% [markdown]
# #### Cluster 3

# %%
cluster_3
# Out:
# Empty DataFrame
# Columns: [transaction_id, transaction_date, transaction_time, transaction_qty, store_id, store_location, product_id, unit_price, product_category, product_type, product_detail, periodo, temporada, KMeans_Clusters]
# Index: []

# %% [markdown]
# #### Cluster 4

# %%
cluster_4
# Out:
# Empty DataFrame
# Columns: [transaction_id, transaction_date, transaction_time, transaction_qty, store_id, store_location, product_id, unit_price, product_category, product_type, product_detail, periodo, temporada, KMeans_Clusters]
# Index: []

# %% [markdown]
# #### Resumen

# %%
cluster_summary = df.groupby('KMeans_Clusters').agg({
    'store_location': lambda x: x.value_counts().index[0],  # Ubicación más común
    'periodo': lambda x: x.value_counts().index[0],         # Hora más común
    'temporada': lambda x: x.value_counts().index[0],# Temporada más común
    'product_category': lambda x: x.value_counts().index[0],# Categoría más común
    'transaction_id': 'count'                               # Cantidad de transacciones
})

# %%
print(cluster_summary)
# Out:
#                  store_location periodo  temporada product_category  \
# KMeans_Clusters
# 0                       Astoria   Tarde  Primavera           Coffee
# 1                Hell's Kitchen  Mañana  Primavera           Coffee
# 2                Hell's Kitchen  Mañana  Primavera              Tea
#
#                  transaction_id
# KMeans_Clusters
# 0                         57179
# 1                         62080
# 2                         29857

# %% [markdown]
# #### Gráfico de barras de transacciones por localidad de cada cluster

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='KMeans_Clusters', hue='store_location')
plt.title("Distribución de ubicaciones por cluster")
plt.show()

# %% [markdown]
# #### Gráfico de barras de transacciones por periodo de cada cluster

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='KMeans_Clusters', hue='periodo')
plt.title("Distribución de periodos por cluster")
plt.show()

# %% [markdown]
# #### Gráfico de barras de transacciones por temporada de cada cluster

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='KMeans_Clusters', hue='temporada')
plt.title("Distribución de temporadas por cluster")
plt.show()

# %% [markdown]
# #### Gráfico de barras de transacciones por categoría de cada cluster

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='KMeans_Clusters', hue='product_category')
plt.title("Distribución de categorías por cluster")
plt.show()

# %% [markdown]
# #### Insights

# %% [markdown]
# ##### Grupo A

# %% [markdown]
# - Suelen concurrir a las tres localidades, pero sobre todo a Lower Manhattan
# - Suelen ir a la mañana y poco a la noche
# - Tienen concurrencia todo el año, pero mayormente en primavera
# - Consumen mucho té y un poco de chocolate

# %% [markdown]
# ##### Grupo B

# %% [markdown]
# - Concurren principalmente a la localidad de Lower Manhattan, pero también a Hell’s Kitchen. No van a Astoria
# - Suelen ir principalmente a la mañana y un poco a la noche
# - Tienen concurrencia todo el año, pero mayormente en primavera
# - Consumen mucho café y también bastante bakery, chocolatada y flavours

# %% [markdown]
# ##### Grupo C

# %% [markdown]
# - Suelen concurrir a las tres localidades, pero sobre todo a Hell’s Kitchen
# - Suelen ir a la tarde y cada tanto a la noche. No van a la mañana
# - Tienen concurrencia todo el año, pero mayormente en primavera
# - Consumen mucho café, bastante bakery y chocolatada

# %% [markdown]
# ##### Grupo D

# %% [markdown]
# - Concurren principalmente a la localidad de Astoria, cada tanto van a Hell’s Kitchen. No van a Lower Manhattan
# - Suelen ir principalmente a la mañana y cada tanto a la noche. No van a la tarde
# - Tienen concurrencia todo el año, pero mayormente en primavera
# - Consumen mucho café, bastante bakery y cada tanto chocolatada

# %% [markdown]
# ##### Grupo E

# %% [markdown]
# - Suelen concurrir a las tres localidades, pero sobre todo a Astoria
# - Suelen ir principalmente a la tarde y cada tanto a la noche
# - Tienen concurrencia todo el año, pero mayormente en primavera
# - Consumen mucho té y un poco de chocolate

# %% [markdown]
# ##### Observaciones Generales

# %% [markdown]
# - El grupo B no va a Astoria y el grupo D no va a Lower Manhattan. El resto suele ir a las tres localidades
# - Los grupos A, B y D suelen ir mucho a la mañana, cada tanto a la noche y no van a la tarde. En cambio, los grupos C y E van mucho a la tarde, cada tanto a la noche y no van a la mañana
# - En todos los grupos se tiene más concurrencia en primavera, le sigue invierno y luego verano
# - A nivel general, se suele consumir café, té, bakery, chocolatada y flavours
